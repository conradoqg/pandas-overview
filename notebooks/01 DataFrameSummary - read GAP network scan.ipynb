# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Load-dataset" data-toc-modified-id="Load-dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load dataset</a></div><div class="lev1 toc-item"><a href="#Create-DataFrameSummary" data-toc-modified-id="Create-DataFrameSummary-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Create DataFrameSummary</a></div><div class="lev1 toc-item"><a href="#columns_stats" data-toc-modified-id="columns_stats-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>columns_stats</a></div><div class="lev1 toc-item"><a href="#get_numeric_summary()" data-toc-modified-id="get_numeric_summary()-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>get_numeric_summary()</a></div><div class="lev1 toc-item"><a href="#summary()" data-toc-modified-id="summary()-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>summary()</a></div><div class="lev1 toc-item"><a href="#_get_list_of_type()" data-toc-modified-id="_get_list_of_type()-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>_get_list_of_type()</a></div>

# %% [markdown]
# > Requires installation of pandas-overview in site-packages

# %% [markdown]
# # Load dataset

# %%
from pandas_overview import DataFrameSummary
import pandas as pd

# %%
df = pd.read_excel("../data/gap_58_dataset.xlsx")
df.head()
# Out:
#    WELL_LABEL   WELL_NAME DP_CONTROL  DP_PRES_DROP GL_CONTROL_MODE  GL_GLIR  \
# 0  DS-2J016-S  DS-2J016-S       NONE             0      CALCULATED    0.154
# 1  DS-2J016-L  DS-2J016-L       NONE             0      FIXEDVALUE    0.000
# 2  DS-2J030-S  DS-2J030-S       NONE             0      FIXEDVALUE      NaN
# 3  DS-2J030-L  DS-2J030-L       NONE             0      CALCULATED    0.200
# 4  DS-2J034-L  DS-2J034-L       NONE             0      CALCULATED    0.120
#
#    GL_MINRT  GL_MAXRT  SOL.GLINJRT  PROSPER.GlINJRT  \
# 0       0.0       1.0     0.143808            0.154
# 1       NaN       NaN     0.000000            0.000
# 2       NaN       NaN     0.000000              NaN
# 3       0.0       1.0     0.009515            0.200
# 4       0.0       1.0     0.192974            0.120
#
#                ...               IPRTYPE        PI  RESPRES  RESTEMP      GOR  \
# 0              ...                    PI  0.005474   2252.0    165.0  24770.0
# 1              ...                    PI  0.304810   2250.0    167.0   2472.0
# 2              ...                    PI  0.149861   1720.0    151.0   1500.0
# 3              ...                    PI  0.366630   2350.0    164.0   1513.0
# 4              ...                    PI  2.863152   2200.0    169.0   1343.0
#
#        SGOIL  SGGAS  CO2       WCUT               Prosper.Filename
# 0  32.000000   0.76  0.0   7.310000  C:\Users\ptech\DS-2J016-S.OUT
# 1  40.099998   0.81  0.0  60.000002  C:\Users\ptech\DS-2J016-L.OUT
# 2  22.700001   0.68  0.0  50.000000  C:\Users\ptech\DS-2J030-S.OUT
# 3  31.000000   0.75  0.0  56.140000  C:\Users\ptech\DS-2J030-L.OUT
# 4  37.000000   0.80  0.0  86.000001  C:\Users\ptech\DS-2J034-L.OUT
#
# [5 rows x 32 columns]

# %% [markdown]
# # Create DataFrameSummary

# %%
dfs = DataFrameSummary(df)

# %%
dfs.columns_types
# Out:
# numeric     19
# constant     7
# unique       3
# bool         3
# Name: types, dtype: int64

# %% [markdown]
# # columns_stats

# %%
dfs.columns_stats
# Out:
#              WELL_LABEL WELL_NAME DP_CONTROL DP_PRES_DROP GL_CONTROL_MODE  \
# counts               58        58         58           58              58
# uniques              58        58          1            1               2
# missing               0         0          0            0               0
# missing_perc         0%        0%         0%           0%              0%
# types            unique    unique   constant     constant            bool
#
#               GL_GLIR  GL_MINRT  GL_MAXRT SOL.GLINJRT PROSPER.GlINJRT  \
# counts             29        24        24          58              29
# uniques            15         1         1          18              15
# missing            29        34        34           0              29
# missing_perc      50%    58.62%    58.62%          0%             50%
# types         numeric  constant  constant     numeric         numeric
#
#                    ...          IPRTYPE       PI  RESPRES  RESTEMP      GOR  \
# counts             ...               58       31       31       31       31
# uniques            ...                1       31       23       12       29
# missing            ...                0       27       27       27       27
# missing_perc       ...               0%   46.55%   46.55%   46.55%   46.55%
# types              ...         constant  numeric  numeric  numeric  numeric
#
#                 SGOIL    SGGAS      CO2     WCUT Prosper.Filename
# counts             31       31       58       31               58
# uniques            10       10        3       28               58
# missing            27       27        0       27                0
# missing_perc   46.55%   46.55%       0%   46.55%               0%
# types         numeric  numeric  numeric  numeric           unique
#
# [5 rows x 32 columns]

# %% [markdown]
# # get_numeric_summary()

# %%
dfs.get_numeric_summary()
# Out:
#                             GL_GLIR SOL.GLINJRT PROSPER.GlINJRT SOLV.OILRT  \
# mean                       0.175552   0.0689655        0.175552    75.7717
# std                        0.151012    0.147095        0.151012    132.773
# variance                  0.0228047   0.0216369       0.0228047    17628.7
# min                               0           0               0          0
# max                             0.5    0.676974             0.5    528.253
# 5%                                0           0               0          0
# 25%                               0           0               0          0
# 50%                           0.196           0           0.196          0
# 75%                             0.3   0.0175155             0.3    122.437
# 95%                          0.3836    0.413319          0.3836    359.894
# iqr                             0.3   0.0175155             0.3    122.437
# kurtosis                   -1.06606     5.96798        -1.06606    2.93537
# skewness                    0.17525     2.46592         0.17525    1.90304
# sum                           5.091           4           5.091    4394.76
# mad                        0.127843    0.103613        0.127843    100.657
# cv                         0.860215     2.13287        0.860215    1.75228
# zeros_num                        10          40              10         36
# zeros_perc                   17.24%      68.97%          17.24%     62.07%
# deviating_of_mean                29           1              29          2
# deviating_of_mean_perc          50%       1.72%             50%      3.45%
# deviating_of_median              29           5              29          6
# deviating_of_median_perc        50%       8.62%             50%     10.34%
# counts                           29          58              29         58
# uniques                          15          18              15         23
# missing                          29           0              29          0
# missing_perc                    50%          0%             50%         0%
# types                       numeric     numeric         numeric    numeric
#
#                          SOLV.GASRT SOLV.LIQRT  SOLV.GLIR SOLV.FWHP SOLV.WCUT  \
# mean                       0.130454    306.113  0.0689655   247.562     60.57
# std                        0.287186    637.334   0.147095   132.723   28.3994
# variance                  0.0824756     406194  0.0216369   17615.5   806.527
# min                               0          0          0   65.0034         0
# max                         1.91938    3250.55   0.676974   758.228     95.46
# 5%                                0          0          0   139.188     1.363
# 25%                               0          0          0   186.167   52.8975
# 50%                               0          0          0   216.086     67.98
# 75%                        0.190826    256.412  0.0175155   277.787     83.86
# 95%                        0.472308     1430.5   0.413319    408.66    89.924
# iqr                        0.190826    256.412  0.0175155   91.6201   30.9625
# kurtosis                    26.5624    9.25974    5.96798   8.80539  0.324233
# skewness                    4.56703    2.89936    2.46592   2.51405  -1.04852
# sum                         7.56633    17754.6          4   6189.05   1332.54
# mad                        0.167714    415.968   0.103613   85.9041   21.6036
# cv                          2.20143    2.08202    2.13287  0.536121  0.468869
# zeros_num                        36         36         42         0         1
# zeros_perc                   62.07%     62.07%     72.41%        0%     1.72%
# deviating_of_mean                 1          2          1        34        36
# deviating_of_mean_perc        1.72%      3.45%      1.72%    58.62%    62.07%
# deviating_of_median               3          5          5        34        36
# deviating_of_median_perc      5.17%      8.62%      8.62%    58.62%    62.07%
# counts                           58         58         58        25        22
# uniques                          23         23         17        25        20
# missing                           0          0          0        33        36
# missing_perc                     0%         0%         0%    56.90%    62.07%
# types                       numeric    numeric    numeric   numeric   numeric
#
#                          SOLV.DDOWN SOLV.THP          PI   RESPRES    RESTEMP  \
# mean                        925.822  106.708     1.02352   2217.87    166.387
# std                         567.676  150.702     1.57396   281.214    8.16773
# variance                     322256  22710.9     2.47736   79081.6    66.7118
# min                               0        0  0.00547368      1720        151
# max                         1981.73  758.228     6.99214      3130        194
# 5%                                0        0   0.0995295      1800        151
# 25%                         522.827        0    0.190918      2045        164
# 50%                         883.054        0     0.30481      2252        168
# 75%                         1394.75  202.668     1.05572    2365.5      170.5
# 95%                         1727.87  328.007     3.94738    2545.5        172
# iqr                         871.923  202.668    0.864805     320.5        6.5
# kurtosis                  -0.919758  4.71147     7.03356   2.50849    3.80644
# skewness                 -0.0642815  1.79548     2.57566  0.764435   0.584757
# sum                         23145.6  6189.05      31.729     68754       5158
# mad                         486.127  122.864     1.06377   203.883    5.63996
# cv                         0.613159  1.41228      1.5378  0.126795  0.0490887
# zeros_num                         3       33           0         0          0
# zeros_perc                    5.17%   56.90%          0%        0%         0%
# deviating_of_mean                33        1          28        28         28
# deviating_of_mean_perc       56.90%    1.72%      48.28%    48.28%     48.28%
# deviating_of_median              33        3          29        28         28
# deviating_of_median_perc     56.90%    5.17%         50%    48.28%     48.28%
# counts                           25       58          31        31         31
# uniques                          23       26          31        23         12
# missing                          33        0          27        27         27
# missing_perc                 56.90%       0%      46.55%    46.55%     46.55%
# types                       numeric  numeric     numeric   numeric    numeric
#
#                                   GOR     SGOIL       SGGAS        CO2  \
# mean                          3866.45   34.0806    0.774839  0.0425862
# std                           6108.82   6.72292    0.056972   0.240851
# variance                  3.73177e+07   45.1976  0.00324581   0.058009
# min                               482      22.7        0.68          0
# max                             24770      41.2        0.86       1.66
# 5%                                732      22.7        0.68          0
# 25%                           1176.25        31        0.75          0
# 50%                              1500        37         0.8          0
# 75%                           2259.32      40.1        0.81          0
# 95%                             18981      41.2        0.86          0
# iqr                           1083.07       9.1        0.06          0
# kurtosis                      5.50463 -0.915593   -0.710382    38.4868
# skewness                      2.52055  -0.68821   -0.507161    6.08497
# sum                            119860    1056.5       24.02       2.47
# mad                              4013   5.80187   0.0475963  0.0822354
# cv                            1.57996  0.197265   0.0735275     5.6556
# zeros_num                           0         0           0         56
# zeros_perc                         0%        0%          0%     96.55%
# deviating_of_mean                  28        27          27          2
# deviating_of_mean_perc         48.28%    46.55%      46.55%      3.45%
# deviating_of_median                30        27          27          2
# deviating_of_median_perc       51.72%    46.55%      46.55%      3.45%
# counts                             31        31          31         58
# uniques                            29        10          10          3
# missing                            27        27          27          0
# missing_perc                   46.55%    46.55%      46.55%         0%
# types                         numeric   numeric     numeric    numeric
#
#                               WCUT
# mean                       60.9255
# std                        25.6041
# variance                    655.57
# min                              0
# max                          96.17
# 5%                            4.18
# 25%                         51.075
# 50%                          62.09
# 75%                         79.715
# 95%                          92.73
# iqr                          28.64
# kurtosis                  0.651417
# skewness                 -0.948269
# sum                        1888.69
# mad                        19.1588
# cv                        0.420253
# zeros_num                        1
# zeros_perc                   1.72%
# deviating_of_mean               27
# deviating_of_mean_perc      46.55%
# deviating_of_median             27
# deviating_of_median_perc    46.55%
# counts                          31
# uniques                         28
# missing                         27
# missing_perc                46.55%
# types                      numeric

# %% [markdown]
# # summary()

# %%
dfs.summary()
# Out:
#              WELL_LABEL WELL_NAME DP_CONTROL DP_PRES_DROP GL_CONTROL_MODE  \
# count               NaN       NaN        NaN           58             NaN
# mean                NaN       NaN        NaN            0             NaN
# std                 NaN       NaN        NaN            0             NaN
# min                 NaN       NaN        NaN            0             NaN
# 25%                 NaN       NaN        NaN            0             NaN
# 50%                 NaN       NaN        NaN            0             NaN
# 75%                 NaN       NaN        NaN            0             NaN
# max                 NaN       NaN        NaN            0             NaN
# counts               58        58         58           58              58
# uniques              58        58          1            1               2
# missing               0         0          0            0               0
# missing_perc         0%        0%         0%           0%              0%
# types            unique    unique   constant     constant            bool
#
#                GL_GLIR  GL_MINRT  GL_MAXRT SOL.GLINJRT PROSPER.GlINJRT  \
# count               29        24        24          58              29
# mean          0.175552         0         1   0.0689655        0.175552
# std           0.151012         0         0    0.147095        0.151012
# min                  0         0         1           0               0
# 25%                  0         0         1           0               0
# 50%              0.196         0         1           0           0.196
# 75%                0.3         0         1   0.0175155             0.3
# max                0.5         0         1    0.676974             0.5
# counts              29        24        24          58              29
# uniques             15         1         1          18              15
# missing             29        34        34           0              29
# missing_perc       50%    58.62%    58.62%          0%             50%
# types          numeric  constant  constant     numeric         numeric
#
#                    ...          IPRTYPE          PI  RESPRES  RESTEMP  \
# count              ...              NaN          31       31       31
# mean               ...              NaN     1.02352  2217.87  166.387
# std                ...              NaN     1.57396  281.214  8.16773
# min                ...              NaN  0.00547368     1720      151
# 25%                ...              NaN    0.190918     2045      164
# 50%                ...              NaN     0.30481     2252      168
# 75%                ...              NaN     1.05572   2365.5    170.5
# max                ...              NaN     6.99214     3130      194
# counts             ...               58          31       31       31
# uniques            ...                1          31       23       12
# missing            ...                0          27       27       27
# missing_perc       ...               0%      46.55%   46.55%   46.55%
# types              ...         constant     numeric  numeric  numeric
#
#                   GOR    SGOIL     SGGAS        CO2     WCUT Prosper.Filename
# count              31       31        31         58       31              NaN
# mean          3866.45  34.0806  0.774839  0.0425862  60.9255              NaN
# std           6108.82  6.72292  0.056972   0.240851  25.6041              NaN
# min               482     22.7      0.68          0        0              NaN
# 25%           1176.25       31      0.75          0   51.075              NaN
# 50%              1500       37       0.8          0    62.09              NaN
# 75%           2259.32     40.1      0.81          0   79.715              NaN
# max             24770     41.2      0.86       1.66    96.17              NaN
# counts             31       31        31         58       31               58
# uniques            29       10        10          3       28               58
# missing            27       27        27          0       27                0
# missing_perc   46.55%   46.55%    46.55%         0%   46.55%               0%
# types         numeric  numeric   numeric    numeric  numeric           unique
#
# [13 rows x 32 columns]

# %% [markdown]
# # _get_list_of_type()

# %%
dfs[dfs._get_list_of_type("numeric")]
# Out:
#                             GL_GLIR SOL.GLINJRT PROSPER.GlINJRT SOLV.OILRT  \
# mean                       0.175552   0.0689655        0.175552    75.7717
# std                        0.151012    0.147095        0.151012    132.773
# variance                  0.0228047   0.0216369       0.0228047    17628.7
# min                               0           0               0          0
# max                             0.5    0.676974             0.5    528.253
# 5%                                0           0               0          0
# 25%                               0           0               0          0
# 50%                           0.196           0           0.196          0
# 75%                             0.3   0.0175155             0.3    122.437
# 95%                          0.3836    0.413319          0.3836    359.894
# iqr                             0.3   0.0175155             0.3    122.437
# kurtosis                   -1.06606     5.96798        -1.06606    2.93537
# skewness                    0.17525     2.46592         0.17525    1.90304
# sum                           5.091           4           5.091    4394.76
# mad                        0.127843    0.103613        0.127843    100.657
# cv                         0.860215     2.13287        0.860215    1.75228
# zeros_num                        10          40              10         36
# zeros_perc                   17.24%      68.97%          17.24%     62.07%
# deviating_of_mean                29           1              29          2
# deviating_of_mean_perc          50%       1.72%             50%      3.45%
# deviating_of_median              29           5              29          6
# deviating_of_median_perc        50%       8.62%             50%     10.34%
# counts                           29          58              29         58
# uniques                          15          18              15         23
# missing                          29           0              29          0
# missing_perc                    50%          0%             50%         0%
# types                       numeric     numeric         numeric    numeric
#
#                          SOLV.GASRT SOLV.LIQRT  SOLV.GLIR SOLV.FWHP SOLV.WCUT  \
# mean                       0.130454    306.113  0.0689655   247.562     60.57
# std                        0.287186    637.334   0.147095   132.723   28.3994
# variance                  0.0824756     406194  0.0216369   17615.5   806.527
# min                               0          0          0   65.0034         0
# max                         1.91938    3250.55   0.676974   758.228     95.46
# 5%                                0          0          0   139.188     1.363
# 25%                               0          0          0   186.167   52.8975
# 50%                               0          0          0   216.086     67.98
# 75%                        0.190826    256.412  0.0175155   277.787     83.86
# 95%                        0.472308     1430.5   0.413319    408.66    89.924
# iqr                        0.190826    256.412  0.0175155   91.6201   30.9625
# kurtosis                    26.5624    9.25974    5.96798   8.80539  0.324233
# skewness                    4.56703    2.89936    2.46592   2.51405  -1.04852
# sum                         7.56633    17754.6          4   6189.05   1332.54
# mad                        0.167714    415.968   0.103613   85.9041   21.6036
# cv                          2.20143    2.08202    2.13287  0.536121  0.468869
# zeros_num                        36         36         42         0         1
# zeros_perc                   62.07%     62.07%     72.41%        0%     1.72%
# deviating_of_mean                 1          2          1        34        36
# deviating_of_mean_perc        1.72%      3.45%      1.72%    58.62%    62.07%
# deviating_of_median               3          5          5        34        36
# deviating_of_median_perc      5.17%      8.62%      8.62%    58.62%    62.07%
# counts                           58         58         58        25        22
# uniques                          23         23         17        25        20
# missing                           0          0          0        33        36
# missing_perc                     0%         0%         0%    56.90%    62.07%
# types                       numeric    numeric    numeric   numeric   numeric
#
#                          SOLV.DDOWN SOLV.THP          PI   RESPRES    RESTEMP  \
# mean                        925.822  106.708     1.02352   2217.87    166.387
# std                         567.676  150.702     1.57396   281.214    8.16773
# variance                     322256  22710.9     2.47736   79081.6    66.7118
# min                               0        0  0.00547368      1720        151
# max                         1981.73  758.228     6.99214      3130        194
# 5%                                0        0   0.0995295      1800        151
# 25%                         522.827        0    0.190918      2045        164
# 50%                         883.054        0     0.30481      2252        168
# 75%                         1394.75  202.668     1.05572    2365.5      170.5
# 95%                         1727.87  328.007     3.94738    2545.5        172
# iqr                         871.923  202.668    0.864805     320.5        6.5
# kurtosis                  -0.919758  4.71147     7.03356   2.50849    3.80644
# skewness                 -0.0642815  1.79548     2.57566  0.764435   0.584757
# sum                         23145.6  6189.05      31.729     68754       5158
# mad                         486.127  122.864     1.06377   203.883    5.63996
# cv                         0.613159  1.41228      1.5378  0.126795  0.0490887
# zeros_num                         3       33           0         0          0
# zeros_perc                    5.17%   56.90%          0%        0%         0%
# deviating_of_mean                33        1          28        28         28
# deviating_of_mean_perc       56.90%    1.72%      48.28%    48.28%     48.28%
# deviating_of_median              33        3          29        28         28
# deviating_of_median_perc     56.90%    5.17%         50%    48.28%     48.28%
# counts                           25       58          31        31         31
# uniques                          23       26          31        23         12
# missing                          33        0          27        27         27
# missing_perc                 56.90%       0%      46.55%    46.55%     46.55%
# types                       numeric  numeric     numeric   numeric    numeric
#
#                                   GOR     SGOIL       SGGAS        CO2  \
# mean                          3866.45   34.0806    0.774839  0.0425862
# std                           6108.82   6.72292    0.056972   0.240851
# variance                  3.73177e+07   45.1976  0.00324581   0.058009
# min                               482      22.7        0.68          0
# max                             24770      41.2        0.86       1.66
# 5%                                732      22.7        0.68          0
# 25%                           1176.25        31        0.75          0
# 50%                              1500        37         0.8          0
# 75%                           2259.32      40.1        0.81          0
# 95%                             18981      41.2        0.86          0
# iqr                           1083.07       9.1        0.06          0
# kurtosis                      5.50463 -0.915593   -0.710382    38.4868
# skewness                      2.52055  -0.68821   -0.507161    6.08497
# sum                            119860    1056.5       24.02       2.47
# mad                              4013   5.80187   0.0475963  0.0822354
# cv                            1.57996  0.197265   0.0735275     5.6556
# zeros_num                           0         0           0         56
# zeros_perc                         0%        0%          0%     96.55%
# deviating_of_mean                  28        27          27          2
# deviating_of_mean_perc         48.28%    46.55%      46.55%      3.45%
# deviating_of_median                30        27          27          2
# deviating_of_median_perc       51.72%    46.55%      46.55%      3.45%
# counts                             31        31          31         58
# uniques                            29        10          10          3
# missing                            27        27          27          0
# missing_perc                   46.55%    46.55%      46.55%         0%
# types                         numeric   numeric     numeric    numeric
#
#                               WCUT
# mean                       60.9255
# std                        25.6041
# variance                    655.57
# min                              0
# max                          96.17
# 5%                            4.18
# 25%                         51.075
# 50%                          62.09
# 75%                         79.715
# 95%                          92.73
# iqr                          28.64
# kurtosis                  0.651417
# skewness                 -0.948269
# sum                        1888.69
# mad                        19.1588
# cv                        0.420253
# zeros_num                        1
# zeros_perc                   1.72%
# deviating_of_mean               27
# deviating_of_mean_perc      46.55%
# deviating_of_median             27
# deviating_of_median_perc    46.55%
# counts                          31
# uniques                         28
# missing                         27
# missing_perc                46.55%
# types                      numeric

# %%
dfs[dfs._get_list_of_type("constant")]
# Out:
#              DP_CONTROL DP_PRES_DROP  GL_MINRT  GL_MAXRT IS_MASKED  \
# top            NONE: 58        0: 58   0.0: 24   1.0: 24     0: 58
# counts               58           58        24        24        58
# uniques               1            1         1         1         1
# missing               0            0        34        34         0
# missing_perc         0%           0%    58.62%    58.62%        0%
# types          constant     constant  constant  constant  constant
#
#                WELLMODEL   IPRTYPE
# top           VLPIPR: 58    PI: 58
# counts                58        58
# uniques                1         1
# missing                0         0
# missing_perc          0%        0%
# types           constant  constant

# %%
dfs[dfs._get_list_of_type("unique")]
# Out:
#              WELL_LABEL WELL_NAME Prosper.Filename
# counts               58        58               58
# uniques              58        58               58
# missing               0         0                0
# missing_perc         0%        0%               0%
# types            unique    unique           unique

# %%
dfs
