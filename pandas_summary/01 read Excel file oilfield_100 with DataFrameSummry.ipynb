# %%
from pandas_summary import DataFrameSummary

# %%
import pandas as pd

# %%
df = pd.read_excel("oilfield_100.xlsx")

# %%
df.head()
# Out:
#        Wellname        Company Analyst  Field Location Platform  Fluid  \
# 0  PSCO-R015-LS  Oil Gains Co.  Litvar  PISCO  R015-LS        R      0
# 1  PSCO-R004-LS  Oil Gains Co.    Mark  PISCO  R004-LS        R      0
# 2  PSCO-R019-SS  Oil Gains Co.  Litvar  PISCO  R019-SS        R      0
# 3  PSCO-R019-LS  Oil Gains Co.  Litvar  PISCO  R019-LS        R      0
# 4  PSCO-R020-SS  Oil Gains Co.  Litvar  PISCO  R020-SS        R      0
#
#    WellType  AL_Method  Completion  \
# 0         0          1           0
# 1         0          1           0
# 2         0          1           0
# 3         0          1           0
# 4         0          1           0
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                         WT_WC  \
# 0                                      85|80|
# ...

# %%
dfs = DataFrameSummary(df)
# Out:
# inside pandas-summary-oct-07

# %%
dfs.columns_stats
# Out:
#                  Wellname   Company      Analyst     Field     Location  \
# counts                100       100           99       100          100
# uniques                98         1           12         1           98
# missing                 0         0            1         0            0
# missing_perc           0%        0%           1%        0%           0%
# types         categorical  constant  categorical  constant  categorical
#
#                  Platform     Fluid  WellType AL_Method Completion  \
# counts                100       100       100       100        100
# uniques                 4         1         1         2          2
# missing                 0         0         0         0          0
# missing_perc           0%        0%        0%        0%         0%
# types         categorical  constant  constant      bool       bool
#
#                    ...              WT_WC       WT_THP       WT_GOR  \
# ...
